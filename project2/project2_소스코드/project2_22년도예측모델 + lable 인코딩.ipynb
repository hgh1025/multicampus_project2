# %% [markdown]
# -- 각 파라미터 예측 --

# %%
import pandas as pd

df=pd.read_csv('C:/multicampus/project2/데이터 전처리/data.csv', encoding='euc-kr')

# %%
df
# Out:
#      year   id  cnt_crime  cnt_cctv  dense_population  cnt_light  cnt_police  \
# 0    2015    0       8617       830             14728       8988          25
# 1    2015    1       5244       154             18842       8651          20
# 2    2015    2       4257       124             14172       6977          13
# 3    2015    3       5585       199             14376       5299          16
# 4    2015    4       6345       609             17891       4981          11
# ..    ...  ...        ...       ...               ...        ...         ...
# 170  2021  170       2381       228             10852       5789          19
# 171  2021  171       3244       471             16061      12593          21
# 172  2021  172       2712         0              6431      14351          23
# 173  2021  173       2861       403             13231      14822          22
# 174  2021  174       3210       448             21188       8126          17
#
# ...

# %%
regions=list(df['region'].unique())
regions
# Out:
# ['gangnam',
#  'gangdong',
#  'gangbuk',
#  'gangseo',
#  'gwanak',
#  'gwangjin',
#  'guro',
#  'geumcheon',
#  'nowon',
#  'dobong',
#  'dongdaemun',
#  'dongjak',
#  'mapo',
#  'seodaemun',
#  'seocho',
#  'seongdong',
#  'seongbuk',
#  'songpa',
#  'yangcheon',
#  'yeongdeungpo',
#  'yongsan',
#  'eunpyeong',
#  'jongno',
#  'jung',
#  'jungnang']

# %%
df_ex=df[df['region'] == 'gangnam']

# %%
df_ex
# Out:
#      year   id  cnt_crime  cnt_cctv  dense_population  cnt_light  cnt_police  \
# 0    2015    0       8617       830             14728       8988          25
# 25   2016   25       8149      1293             14484       8988          25
# 50   2017   50       7720       988             14203       8986          25
# 75   2018   75       7513       745             13859       9220          25
# 100  2019  100       7304       791             13929       9265          25
# 125  2020  125       7356       926             13773       8818          24
# 150  2021  150       6146       516             13616       7947          24
#
#      female_population  cnt_notify  cnt_population   region
# 0               282162      169303          581760  gangnam
# 25              277824      167991          572140  gangnam
# 50              272427      170135          561052  gangnam
# 75              264231      168832          547453  gangnam
# ...

# %%
df_expect=pd.DataFrame(columns=['cnt_crime','cnt_cctv','dense_population','cnt_light','cnt_police','female_population','cnt_notify','cnt_population'],index=regions)

# %%
df_expect.head()
# Out:
#          cnt_crime cnt_cctv dense_population cnt_light cnt_police  \
# gangnam        NaN      NaN              NaN       NaN        NaN
# gangdong       NaN      NaN              NaN       NaN        NaN
# gangbuk        NaN      NaN              NaN       NaN        NaN
# gangseo        NaN      NaN              NaN       NaN        NaN
# gwanak         NaN      NaN              NaN       NaN        NaN
#
#          female_population cnt_notify cnt_population
# gangnam                NaN        NaN            NaN
# gangdong               NaN        NaN            NaN
# gangbuk                NaN        NaN            NaN
# gangseo                NaN        NaN            NaN
# gwanak                 NaN        NaN            NaN

# %%
from sklearn.linear_model import LinearRegression
import math

for r in regions:
  df_ex=df[df['region'] == r] # 특정구 df 추출

  X=df_ex['year'] # 년도 추출
  y_lists=['cnt_crime','cnt_cctv','dense_population','cnt_light','cnt_police','female_population','cnt_notify','cnt_population'] # 다양하게 뽑아낼 파라미터

  for l in y_lists: # 하나씩 예측해보자
    y=df_ex[l] # 특정구 하나의 파라미터 추출

    reg = LinearRegression().fit(X.values.reshape(-1,1), y) # 학습
    # reg.predict([[2022]]) # 예측

    print(r+'의 '+l+'는 '+'-> '+str(math.floor(reg.predict([[2022]]))))
    df_expect[l][r]=int(math.floor(reg.predict([[2022]])))
  print('\n')
# Out:
# gangnam의 cnt_crime는 -> 6198
# gangnam의 cnt_cctv는 -> 602
# gangnam의 dense_population는 -> 13365
# gangnam의 cnt_light는 -> 8432
# gangnam의 cnt_police는 -> 24
# gangnam의 female_population는 -> 240680
# gangnam의 cnt_notify는 -> 173179
# gangnam의 cnt_population는 -> 527939
#
#
# gangdong의 cnt_crime는 -> 3170
# gangdong의 cnt_cctv는 -> 495
# gangdong의 dense_population는 -> 18563
# gangdong의 cnt_light는 -> 8603
# gangdong의 cnt_police는 -> 19
# gangdong의 female_population는 -> 210837
# gangdong의 cnt_notify는 -> 88105
# gangdong의 cnt_population는 -> 456495
#
#
# gangbuk의 cnt_crime는 -> 2269
# gangbuk의 cnt_cctv는 -> 842
# gangbuk의 dense_population는 -> 12733
# gangbuk의 cnt_light는 -> 8032
# gangbuk의 cnt_police는 -> 13
# gangbuk의 female_population는 -> 142866
# gangbuk의 cnt_notify는 -> 69613
# gangbuk의 cnt_population는 -> 300529
#
#
# gangseo의 cnt_crime는 -> 3812
# gangseo의 cnt_cctv는 -> 420
# gangseo의 dense_population는 -> 14074
# gangseo의 cnt_light는 -> 6484
# gangseo의 cnt_police는 -> 16
# ...

# %%
df_expect #22년도 예측 데이터
# Out:
#    cnt_crime cnt_cctv dense_population cnt_light cnt_police female_population  \
# 0       6198      602            13365      8432         24            240680
# 1       3170      495            18563      8603         19            210837
# 2       2269      842            12733      8032         13            142866
# 3       3812      420            14074      6484         16            278509
# 4       4410      280            16901      4802         13            248140
# 5       2564      683            20708      8461         20            173901
# 6       3433      553            20878      6828         17            203037
# 7       2263      307            18802      5833         26            119173
# 8       3205      220            14253      4311         14            237449
# 9       1811      442            15339      4654          9            147435
# 10      2696      164            24634      9736         15            171740
# ...

# %%
df_expect['region']=df_expect.index
df_expect.index=range(0,25)
df_expect
# Out:
#    cnt_crime cnt_cctv dense_population cnt_light cnt_police female_population  \
# 0       6198      602            13365      8432         24            240680
# 1       3170      495            18563      8603         19            210837
# 2       2269      842            12733      8032         13            142866
# 3       3812      420            14074      6484         16            278509
# 4       4410      280            16901      4802         13            248140
# 5       2564      683            20708      8461         20            173901
# 6       3433      553            20878      6828         17            203037
# 7       2263      307            18802      5833         26            119173
# 8       3205      220            14253      4311         14            237449
# 9       1811      442            15339      4654          9            147435
# 10      2696      164            24634      9736         15            171740
# ...

# %%
df_past=pd.read_csv('C:/multicampus/project2/데이터 전처리/data.csv', encoding='euc-kr')

# %%
df_past
# Out:
#      year   id  cnt_crime  cnt_cctv  dense_population  cnt_light  cnt_police  \
# 0    2015    0       8617       830             14728       8988          25
# 1    2015    1       5244       154             18842       8651          20
# 2    2015    2       4257       124             14172       6977          13
# 3    2015    3       5585       199             14376       5299          16
# 4    2015    4       6345       609             17891       4981          11
# ..    ...  ...        ...       ...               ...        ...         ...
# 170  2021  170       2381       228             10852       5789          19
# 171  2021  171       3244       471             16061      12593          21
# 172  2021  172       2712         0              6431      14351          23
# 173  2021  173       2861       403             13231      14822          22
# 174  2021  174       3210       448             21188       8126          17
#
# ...

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
df_past['region']=le.fit_transform(df_past['region'])
df_expect['region']=le.transform(df_expect['region'])

# %%
df_past.head()
# Out:
#    year  id  cnt_crime  cnt_cctv  dense_population  cnt_light  cnt_police  \
# 0  2015   0       8617       830             14728       8988          25
# 1  2015   1       5244       154             18842       8651          20
# 2  2015   2       4257       124             14172       6977          13
# 3  2015   3       5585       199             14376       5299          16
# 4  2015   4       6345       609             17891       4981          11
#
#    female_population  cnt_notify  cnt_population  region
# 0             282162      169303          581760       6
# 1             223788       94193          463321       5
# 2             163606       79634          334426       4
# 3             292237      116561          595691       7
# 4             257655      113627          529031      10

# %%
df_expect.head()
# Out:
#   cnt_crime cnt_cctv dense_population cnt_light cnt_police female_population  \
# 0      6198      602            13365      8432         24            240680
# 1      3170      495            18563      8603         19            210837
# 2      2269      842            12733      8032         13            142866
# 3      3812      420            14074      6484         16            278509
# 4      4410      280            16901      4802         13            248140
#
#   cnt_notify cnt_population  region
# 0     173179         527939       6
# 1      88105         456495       5
# 2      69613         300529       4
# 3     115134         583349       7
# 4     115675         499749      10

# %%
X=df_past.drop(['year','id','cnt_notify'],axis=1)
y=df_past['cnt_notify']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
import numpy as np

regr = LinearRegression()
regr.fit(X_train, y_train)

y_test_pred=regr.predict(X_test)
print(regr.score(X_test,y_test))

scores = cross_val_score(regr, X, y)
print(scores.mean())

print(mean_absolute_error(y_test, y_test_pred))
print(mean_squared_error(y_test, y_test_pred))
MSE = mean_squared_error(y_test, y_test_pred) 
print(np.sqrt(MSE))
# Out:
# 0.4927424295255639
# 0.42618845342128164
# 13665.558305121674
# 331935977.66772825
# 18219.110232602696

# %%
df_expect['cnt_notify']= 0

# %%
df_expect.head()
# Out:
#   cnt_crime cnt_cctv dense_population cnt_light cnt_police female_population  \
# 0      6198      602            13365      8432         24            240680
# 1      3170      495            18563      8603         19            210837
# 2      2269      842            12733      8032         13            142866
# 3      3812      420            14074      6484         16            278509
# 4      4410      280            16901      4802         13            248140
#
#    cnt_notify cnt_population  region
# 0           0         527939       6
# 1           0         456495       5
# 2           0         300529       4
# 3           0         583349       7
# 4           0         499749      10

# %%
df_expect['cnt_notify']=regr.predict(df_expect.drop(['cnt_notify'],axis=1))

# %%
df_past['region']=le.inverse_transform(df_past['region'])
df_expect['region']=le.inverse_transform(df_expect['region'])

# %%
df_expect['year']= 2022
df_expect['id']= df_expect.index

# %%
df_expect['cnt_notify']=df_expect['cnt_notify'].astype('int64')

# %%
df_past.head() #15년~21년 데이터
# Out:
#    year  id  cnt_crime  cnt_cctv  dense_population  cnt_light  cnt_police  \
# 0  2015   0       8617       830             14728       8988          25
# 1  2015   1       5244       154             18842       8651          20
# 2  2015   2       4257       124             14172       6977          13
# 3  2015   3       5585       199             14376       5299          16
# 4  2015   4       6345       609             17891       4981          11
#
#    female_population  cnt_notify  cnt_population    region
# 0             282162      169303          581760   gangnam
# 1             223788       94193          463321  gangdong
# 2             163606       79634          334426   gangbuk
# 3             292237      116561          595691   gangseo
# 4             257655      113627          529031    gwanak

# %%
df_expect.head() # 22년 예측 데이터
# Out:
#   cnt_crime cnt_cctv dense_population cnt_light cnt_police female_population  \
# 0      6198      602            13365      8432         24            240680
# 1      3170      495            18563      8603         19            210837
# 2      2269      842            12733      8032         13            142866
# 3      3812      420            14074      6484         16            278509
# 4      4410      280            16901      4802         13            248140
#
#    cnt_notify cnt_population  region  year  id
# 0      122966         527939       0  2022   0
# 1       74051         456495       1  2022   1
# 2       77153         300529       2  2022   2
# 3       81228         583349       3  2022   3
# 4       88507         499749       4  2022   4

# %%
df_expect.to_csv('C:/multicampus/project2/데이터 전처리/expect_2022.csv',index=False)

# %%
#lable encoding

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
df_past['region']=le.fit_transform(df_past['region'])

# %%
X=df_past.drop(['year','id','cnt_notify'],axis=1)
y=df_past['cnt_notify']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
import numpy as np

regr = LinearRegression()
regr.fit(X_train, y_train)

y_test_pred=regr.predict(X_test)
print(regr.score(X_test,y_test))

scores = cross_val_score(regr, X, y)
print(scores.mean())

print(mean_absolute_error(y_test, y_test_pred))
print(mean_squared_error(y_test, y_test_pred))
MSE = mean_squared_error(y_test, y_test_pred) 
print(np.sqrt(MSE))
# Out:
# 0.4927424295255639
# 0.42618845342128164
# 13665.558305121674
# 331935977.66772825
# 18219.110232602696
